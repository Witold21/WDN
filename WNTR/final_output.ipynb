# %% [markdown]
# ## External imports

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Internal libraries imports

# %%
import wntr_WSN
import networkx_graph as ng
import linear_regression as lr

# %% [markdown]
# ## Input data

# %%
method = 'method'                              # for file naming
leak_node = 'J64'                             # node that's leaking
comment = ''                                   # last word(s) in output filename
leak_start = 48                                # in hours
leak_end = 73                                  # in hours
leak_area = 0.0005
sim_duration = 130                             # total duration of the simulation

# %% [markdown]
# ## Model each node with linear regression

# %%
linreg_models, normalization_params = lr.model_network_with_linreg(n=3)
# Out:
# Modeling the network with linreg (linear_regression.py - model_network_with_linregression())
# Creating a NetworkX graph from .inp file (networkx_graph.py - create_graph())
# Running the simulation (wntr_WSN.py - get_sim_results())
# C:\Users\wij\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\scipy\optimize\minpack.py:829: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 	Modeling junction J1: (1 out of 309)
# 	Modeling junction J2: (2 out of 309)
# 	Modeling junction J3: (3 out of 309)
# 	Modeling junction J4: (4 out of 309)
# 	Modeling junction J5: (5 out of 309)
# 	Modeling junction J6: (6 out of 309)
# 	Modeling junction J7: (7 out of 309)
# 	Modeling junction J8: (8 out of 309)
# 	Modeling junction J9: (9 out of 309)
# 	Modeling junction J10: (10 out of 309)
# 	Modeling junction J11: (11 out of 309)
# 	Modeling junction J12: (12 out of 309)
# 	Modeling junction J13: (13 out of 309)
# 	Modeling junction J14: (14 out of 309)
# 	Modeling junction J15: (15 out of 309)
# 	Modeling junction J16: (16 out of 309)
# 	Modeling junction J17: (17 out of 309)
# 	Modeling junction J18: (18 out of 309)
# 	Modeling junction J19: (19 out of 309)
# 	Modeling junction J20: (20 out of 309)
# 	Modeling junction J21: (21 out of 309)
# 	Modeling junction J22: (22 out of 309)
# 	Modeling junction J24: (23 out of 309)
# 	Modeling junction J25: (24 out of 309)
# 	Modeling junction J26: (25 out of 309)
# 	Modeling junction J27: (26 out of 309)
# 	Modeling junction J28: (27 out of 309)
# 	Modeling junction J29: (28 out of 309)
# 	Modeling junction J30: (29 out of 309)
# 	Modeling junction J31: (30 out of 309)
# 	Modeling junction J32: (31 out of 309)
# 	Modeling junction J33: (32 out of 309)
# 	Modeling junction J34: (33 out of 309)
# 	Modeling junction J35: (34 out of 309)
# 	Modeling junction J36: (35 out of 309)
# 	Modeling junction J37: (36 out of 309)
# 	Modeling junction J38: (37 out of 309)
# 	Modeling junction J39: (38 out of 309)
# 	Modeling junction J40: (39 out of 309)
# 	Modeling junction J41: (40 out of 309)
# 	Modeling junction J42: (41 out of 309)
# 	Modeling junction J43: (42 out of 309)
# 	Modeling junction J44: (43 out of 309)
# 	Modeling junction J45: (44 out of 309)
# 	Modeling junction J46: (45 out of 309)
# 	Modeling junction J47: (46 out of 309)
# 	Modeling junction J48: (47 out of 309)
# 	Modeling junction J49: (48 out of 309)
# 	Modeling junction J50: (49 out of 309)
# 	Modeling junction J52: (50 out of 309)
# 	Modeling junction J53: (51 out of 309)
# 	Modeling junction J54: (52 out of 309)
# 	Modeling junction J56: (53 out of 309)
# 	Modeling junction J57: (54 out of 309)
# 	Modeling junction J58: (55 out of 309)
# 	Modeling junction J59: (56 out of 309)
# 	Modeling junction J60: (57 out of 309)
# 	Modeling junction J61: (58 out of 309)
# 	Modeling junction J62: (59 out of 309)
# 	Modeling junction J63: (60 out of 309)
# 	Modeling junction J64: (61 out of 309)
# 	Modeling junction J65: (62 out of 309)
# 	Modeling junction J66: (63 out of 309)
# 	Modeling junction J67: (64 out of 309)
# 	Modeling junction J68: (65 out of 309)
# 	Modeling junction J69: (66 out of 309)
# 	Modeling junction J70: (67 out of 309)
# 	Modeling junction J71: (68 out of 309)
# 	Modeling junction J72: (69 out of 309)
# 	Modeling junction J73: (70 out of 309)
# 	Modeling junction J75: (71 out of 309)
# 	Modeling junction J76: (72 out of 309)
# 	Modeling junction J77: (73 out of 309)
# 	Modeling junction J78: (74 out of 309)
# 	Modeling junction J79: (75 out of 309)
# 	Modeling junction J80: (76 out of 309)
# 	Modeling junction J81: (77 out of 309)
# 	Modeling junction J82: (78 out of 309)
# 	Modeling junction J83: (79 out of 309)
# 	Modeling junction J84: (80 out of 309)
# 	Modeling junction J85: (81 out of 309)
# 	Modeling junction J86: (82 out of 309)
# 	Modeling junction J87: (83 out of 309)
# 	Modeling junction J88: (84 out of 309)
# 	Modeling junction J89: (85 out of 309)
# 	Modeling junction J90: (86 out of 309)
# 	Modeling junction J91: (87 out of 309)
# 	Modeling junction J92: (88 out of 309)
# 	Modeling junction J93: (89 out of 309)
# 	Modeling junction J94: (90 out of 309)
# 	Modeling junction J95: (91 out of 309)
# 	Modeling junction J96: (92 out of 309)
# 	Modeling junction J97: (93 out of 309)
# 	Modeling junction J98: (94 out of 309)
# 	Modeling junction J99: (95 out of 309)
# 	Modeling junction J100: (96 out of 309)
# 	Modeling junction J102: (97 out of 309)
# 	Modeling junction J103: (98 out of 309)
# 	Modeling junction J104: (99 out of 309)
# 	Modeling junction J105: (100 out of 309)
# 	Modeling junction J106: (101 out of 309)
# 	Modeling junction J107: (102 out of 309)
# 	Modeling junction J108: (103 out of 309)
# 	Modeling junction J109: (104 out of 309)
# 	Modeling junction J110: (105 out of 309)
# 	Modeling junction J111: (106 out of 309)
# 	Modeling junction J112: (107 out of 309)
# 	Modeling junction J113: (108 out of 309)
# 	Modeling junction J114: (109 out of 309)
# 	Modeling junction J115: (110 out of 309)
# 	Modeling junction J116: (111 out of 309)
# 	Modeling junction J117: (112 out of 309)
# 	Modeling junction J118: (113 out of 309)
# 	Modeling junction J119: (114 out of 309)
# 	Modeling junction J120: (115 out of 309)
# 	Modeling junction J121: (116 out of 309)
# 	Modeling junction J122: (117 out of 309)
# 	Modeling junction J123: (118 out of 309)
# 	Modeling junction J124: (119 out of 309)
# 	Modeling junction J125: (120 out of 309)
# 	Modeling junction J126: (121 out of 309)
# 	Modeling junction J127: (122 out of 309)
# 	Modeling junction J128: (123 out of 309)
# 	Modeling junction J129: (124 out of 309)
# 	Modeling junction J130: (125 out of 309)
# 	Modeling junction J131: (126 out of 309)
# 	Modeling junction J132: (127 out of 309)
# 	Modeling junction J133: (128 out of 309)
# 	Modeling junction J134: (129 out of 309)
# 	Modeling junction J135: (130 out of 309)
# 	Modeling junction J136: (131 out of 309)
# 	Modeling junction J137: (132 out of 309)
# 	Modeling junction J138: (133 out of 309)
# 	Modeling junction J139: (134 out of 309)
# 	Modeling junction J140: (135 out of 309)
# 	Modeling junction J141: (136 out of 309)
# 	Modeling junction J142: (137 out of 309)
# 	Modeling junction J143: (138 out of 309)
# 	Modeling junction J144: (139 out of 309)
# 	Modeling junction J145: (140 out of 309)
# 	Modeling junction J146: (141 out of 309)
# 	Modeling junction J147: (142 out of 309)
# 	Modeling junction J148: (143 out of 309)
# 	Modeling junction J149: (144 out of 309)
# 	Modeling junction J150: (145 out of 309)
# 	Modeling junction J151: (146 out of 309)
# 	Modeling junction J153: (147 out of 309)
# 	Modeling junction J154: (148 out of 309)
# 	Modeling junction J155: (149 out of 309)
# 	Modeling junction J156: (150 out of 309)
# 	Modeling junction J157: (151 out of 309)
# 	Modeling junction J158: (152 out of 309)
# 	Modeling junction J159: (153 out of 309)
# 	Modeling junction J160: (154 out of 309)
# 	Modeling junction J161: (155 out of 309)
# 	Modeling junction J162: (156 out of 309)
# 	Modeling junction J163: (157 out of 309)
# 	Modeling junction J164: (158 out of 309)
# 	Modeling junction J165: (159 out of 309)
# 	Modeling junction J166: (160 out of 309)
# 	Modeling junction J167: (161 out of 309)
# 	Modeling junction J168: (162 out of 309)
# 	Modeling junction J169: (163 out of 309)
# 	Modeling junction J170: (164 out of 309)
# 	Modeling junction J171: (165 out of 309)
# 	Modeling junction J172: (166 out of 309)
# 	Modeling junction J173: (167 out of 309)
# 	Modeling junction J175: (168 out of 309)
# 	Modeling junction J176: (169 out of 309)
# 	Modeling junction J177: (170 out of 309)
# 	Modeling junction J179: (171 out of 309)
# 	Modeling junction J180: (172 out of 309)
# 	Modeling junction J181: (173 out of 309)
# 	Modeling junction J182: (174 out of 309)
# 	Modeling junction J183: (175 out of 309)
# 	Modeling junction J184: (176 out of 309)
# 	Modeling junction J185: (177 out of 309)
# 	Modeling junction J186: (178 out of 309)
# 	Modeling junction J187: (179 out of 309)
# 	Modeling junction J188: (180 out of 309)
# 	Modeling junction J189: (181 out of 309)
# 	Modeling junction J190: (182 out of 309)
# 	Modeling junction J191: (183 out of 309)
# 	Modeling junction J192: (184 out of 309)
# 	Modeling junction J193: (185 out of 309)
# 	Modeling junction J194: (186 out of 309)
# 	Modeling junction J195: (187 out of 309)
# 	Modeling junction J196: (188 out of 309)
# 	Modeling junction J197: (189 out of 309)
# 	Modeling junction J198: (190 out of 309)
# 	Modeling junction J199: (191 out of 309)
# 	Modeling junction J200: (192 out of 309)
# 	Modeling junction J202: (193 out of 309)
# 	Modeling junction J203: (194 out of 309)
# 	Modeling junction J204: (195 out of 309)
# 	Modeling junction J205: (196 out of 309)
# 	Modeling junction J206: (197 out of 309)
# 	Modeling junction J207: (198 out of 309)
# 	Modeling junction J208: (199 out of 309)
# 	Modeling junction J209: (200 out of 309)
# 	Modeling junction J210: (201 out of 309)
# 	Modeling junction J211: (202 out of 309)
# 	Modeling junction J212: (203 out of 309)
# 	Modeling junction J213: (204 out of 309)
# 	Modeling junction J214: (205 out of 309)
# 	Modeling junction J216: (206 out of 309)
# 	Modeling junction J218: (207 out of 309)
# 	Modeling junction J219: (208 out of 309)
# 	Modeling junction J220: (209 out of 309)
# 	Modeling junction J223: (210 out of 309)
# 	Modeling junction J224: (211 out of 309)
# 	Modeling junction J225: (212 out of 309)
# 	Modeling junction J226: (213 out of 309)
# 	Modeling junction J227: (214 out of 309)
# 	Modeling junction J228: (215 out of 309)
# 	Modeling junction J229: (216 out of 309)
# 	Modeling junction J230: (217 out of 309)
# 	Modeling junction J231: (218 out of 309)
# 	Modeling junction J232: (219 out of 309)
# 	Modeling junction J233: (220 out of 309)
# 	Modeling junction J235: (221 out of 309)
# 	Modeling junction J236: (222 out of 309)
# 	Modeling junction J239: (223 out of 309)
# 	Modeling junction J240: (224 out of 309)
# 	Modeling junction J241: (225 out of 309)
# 	Modeling junction J242: (226 out of 309)
# 	Modeling junction J243: (227 out of 309)
# 	Modeling junction J244: (228 out of 309)
# 	Modeling junction J245: (229 out of 309)
# 	Modeling junction J246: (230 out of 309)
# 	Modeling junction J247: (231 out of 309)
# 	Modeling junction J248: (232 out of 309)
# 	Modeling junction J249: (233 out of 309)
# 	Modeling junction J250: (234 out of 309)
# 	Modeling junction J251: (235 out of 309)
# 	Modeling junction J252: (236 out of 309)
# 	Modeling junction J253: (237 out of 309)
# 	Modeling junction J254: (238 out of 309)
# 	Modeling junction J256: (239 out of 309)
# 	Modeling junction J257: (240 out of 309)
# 	Modeling junction J258: (241 out of 309)
# 	Modeling junction J259: (242 out of 309)
# 	Modeling junction J260: (243 out of 309)
# 	Modeling junction J261: (244 out of 309)
# 	Modeling junction J262: (245 out of 309)
# 	Modeling junction J263: (246 out of 309)
# 	Modeling junction J264: (247 out of 309)
# 	Modeling junction J265: (248 out of 309)
# 	Modeling junction J267: (249 out of 309)
# 	Modeling junction J269: (250 out of 309)
# 	Modeling junction J273: (251 out of 309)
# 	Modeling junction J274: (252 out of 309)
# 	Modeling junction J275: (253 out of 309)
# 	Modeling junction J276: (254 out of 309)
# 	Modeling junction J277: (255 out of 309)
# 	Modeling junction J278: (256 out of 309)
# 	Modeling junction J279: (257 out of 309)
# 	Modeling junction J280: (258 out of 309)
# 	Modeling junction J281: (259 out of 309)
# 	Modeling junction J282: (260 out of 309)
# 	Modeling junction J283: (261 out of 309)
# 	Modeling junction J284: (262 out of 309)
# 	Modeling junction J285: (263 out of 309)
# 	Modeling junction J286: (264 out of 309)
# 	Modeling junction J287: (265 out of 309)
# 	Modeling junction J288: (266 out of 309)
# 	Modeling junction J289: (267 out of 309)
# 	Modeling junction J290: (268 out of 309)
# 	Modeling junction J291: (269 out of 309)
# 	Modeling junction J292: (270 out of 309)
# 	Modeling junction J293: (271 out of 309)
# 	Modeling junction J294: (272 out of 309)
# 	Modeling junction J295: (273 out of 309)
# 	Modeling junction J296: (274 out of 309)
# 	Modeling junction J297: (275 out of 309)
# 	Modeling junction J298: (276 out of 309)
# 	Modeling junction J299: (277 out of 309)
# 	Modeling junction J300: (278 out of 309)
# 	Modeling junction J301: (279 out of 309)
# 	Modeling junction J302: (280 out of 309)
# 	Modeling junction J303: (281 out of 309)
# 	Modeling junction J304: (282 out of 309)
# 	Modeling junction J305: (283 out of 309)
# 	Modeling junction J306: (284 out of 309)
# 	Modeling junction J307: (285 out of 309)
# 	Modeling junction J308: (286 out of 309)
# 	Modeling junction J309: (287 out of 309)
# 	Modeling junction J310: (288 out of 309)
# 	Modeling junction J311: (289 out of 309)
# 	Modeling junction J312: (290 out of 309)
# 	Modeling junction J313: (291 out of 309)
# 	Modeling junction J314: (292 out of 309)
# 	Modeling junction J315: (293 out of 309)
# 	Modeling junction J316: (294 out of 309)
# 	Modeling junction J317: (295 out of 309)
# 	Modeling junction J318: (296 out of 309)
# 	Modeling junction J319: (297 out of 309)
# 	Modeling junction J320: (298 out of 309)
# 	Modeling junction J321: (299 out of 309)
# 	Modeling junction J322: (300 out of 309)
# 	Modeling junction J323: (301 out of 309)
# 	Modeling junction J324: (302 out of 309)
# 	Modeling junction J326: (303 out of 309)
# 	Modeling junction J327: (304 out of 309)
# 	Modeling junction J539: (305 out of 309)
# 	Modeling junction J544: (306 out of 309)
# 	Modeling junction J546: (307 out of 309)
# 	Modeling junction T1: (308 out of 309)
# 	Modeling junction T2: (309 out of 309)

# %%
linreg_models
# Out:
# [{'node': 'J1',
#   'linreg': LinearRegression(),
#   'msq': 5.637341226912175e-05,
#   'r2': 0.9999686251938643,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J2',
#   'linreg': LinearRegression(),
#   'msq': 5.978548504308501e-06,
#   'r2': 0.9999963379189123,
#   'sensors': ['J284', 'P460', 'P9']},
#  {'node': 'J3',
#   'linreg': LinearRegression(),
#   'msq': 3.4779785988136976e-06,
#   'r2': 0.9999979014912568,
#   'sensors': ['J284', 'P460', 'P9']},
#  {'node': 'J4',
#   'linreg': LinearRegression(),
#   'msq': 1.1570697641537868e-05,
#   'r2': 0.9999929627215727,
#   'sensors': ['J284', 'P460', 'P9']},
#  {'node': 'J5',
#   'linreg': LinearRegression(),
#   'msq': 3.666036758666608e-05,
#   'r2': 0.9999764201230342,
#   'sensors': ['J284', 'P460', 'P9']},
#  {'node': 'J6',
#   'linreg': LinearRegression(),
#   'msq': 0.00022031214051558388,
#   'r2': 0.9998898148577574,
#   'sensors': ['P9', 'J79', 'P500']},
#  {'node': 'J7',
#   'linreg': LinearRegression(),
#   'msq': 7.921957869642725e-05,
#   'r2': 0.999950449668531,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J8',
#   'linreg': LinearRegression(),
#   'msq': 5.7167430219663744e-05,
#   'r2': 0.9999682731334995,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J9',
#   'linreg': LinearRegression(),
#   'msq': 5.535556878547558e-05,
#   'r2': 0.9999550742217451,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J10',
#   'linreg': LinearRegression(),
#   'msq': 0.00013506449639235493,
#   'r2': 0.999910543644834,
#   'sensors': ['P9', 'J79', 'P500']},
#  {'node': 'J11',
#   'linreg': LinearRegression(),
#   'msq': 4.464250380771452e-05,
#   'r2': 0.9999689541962723,
#   'sensors': ['P9', 'J12', 'J79']},
#  {'node': 'J12',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J12', 'P9', 'P13']},
#  {'node': 'J13',
#   'linreg': LinearRegression(),
#   'msq': 2.1880782027356017e-06,
#   'r2': 0.9999987006896097,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J14',
#   'linreg': LinearRegression(),
#   'msq': 3.85582072602205e-06,
#   'r2': 0.9999978285083118,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J15',
#   'linreg': LinearRegression(),
#   'msq': 1.7736520211978556e-06,
#   'r2': 0.9999988393500077,
#   'sensors': ['P13', 'J17', 'J12']},
#  {'node': 'J16',
#   'linreg': LinearRegression(),
#   'msq': 4.7092044610420243e-07,
#   'r2': 0.9999996259568674,
#   'sensors': ['P13', 'J17', 'J12']},
#  {'node': 'J17',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J17', 'P13', 'J12']},
#  {'node': 'J18',
#   'linreg': LinearRegression(),
#   'msq': 2.7729850051306155e-06,
#   'r2': 0.9999981740994645,
#   'sensors': ['J17', 'P13', 'P536']},
#  {'node': 'J19',
#   'linreg': LinearRegression(),
#   'msq': 5.03525798156093e-06,
#   'r2': 0.9999979114577917,
#   'sensors': ['J17', 'P536', 'P13']},
#  {'node': 'J20',
#   'linreg': LinearRegression(),
#   'msq': 6.120607019552898e-06,
#   'r2': 0.9999954213143939,
#   'sensors': ['J17', 'P536', 'P13']},
#  {'node': 'J21',
#   'linreg': LinearRegression(),
#   'msq': 2.5331569635916872e-06,
#   'r2': 0.9999986647297582,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J22',
#   'linreg': LinearRegression(),
#   'msq': 9.823144557698527e-07,
#   'r2': 0.9999995667852566,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J24',
#   'linreg': LinearRegression(),
#   'msq': 0.002323075507033806,
#   'r2': 0.9986091023277537,
#   'sensors': ['P539', 'J539', 'P460']},
#  {'node': 'J25',
#   'linreg': LinearRegression(),
#   'msq': 0.00011434049270126708,
#   'r2': 0.9999704337638994,
#   'sensors': ['P22', 'J316', 'J28']},
#  {'node': 'J26',
#   'linreg': LinearRegression(),
#   'msq': 3.7427774651203616e-05,
#   'r2': 0.999988355673042,
#   'sensors': ['P22', 'J28', 'J316']},
#  {'node': 'J27',
#   'linreg': LinearRegression(),
#   'msq': 2.021066144779424e-05,
#   'r2': 0.9999949290426885,
#   'sensors': ['P22', 'J28', 'J316']},
#  {'node': 'J28',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J28', 'P22', 'J316']},
#  {'node': 'J29',
#   'linreg': LinearRegression(),
#   'msq': 1.6408966420721196e-05,
#   'r2': 0.9999949063037907,
#   'sensors': ['J28', 'P22', 'P27']},
#  {'node': 'J30',
#   'linreg': LinearRegression(),
#   'msq': 9.927002862811597e-05,
#   'r2': 0.9999572852507165,
#   'sensors': ['J28', 'P27', 'P22']},
#  {'node': 'J31',
#   'linreg': LinearRegression(),
#   'msq': 1.1517496758779691e-06,
#   'r2': 0.9999993607612416,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J32',
#   'linreg': LinearRegression(),
#   'msq': 7.682628534028601e-07,
#   'r2': 0.9999996981237312,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J33',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J33', 'P27', 'J151']},
#  {'node': 'J34',
#   'linreg': LinearRegression(),
#   'msq': 2.3339392199850516e-05,
#   'r2': 0.999992888940758,
#   'sensors': ['J316', 'P22', 'P520']},
#  {'node': 'J35',
#   'linreg': LinearRegression(),
#   'msq': 9.807978470162776e-07,
#   'r2': 0.9999997092662987,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J36',
#   'linreg': LinearRegression(),
#   'msq': 9.734534336653797e-06,
#   'r2': 0.9999960711683881,
#   'sensors': ['P520', 'J316', 'J39']},
#  {'node': 'J37',
#   'linreg': LinearRegression(),
#   'msq': 1.2111477973234952e-05,
#   'r2': 0.9999954552608104,
#   'sensors': ['P520', 'J316', 'J39']},
#  {'node': 'J38',
#   'linreg': LinearRegression(),
#   'msq': 8.796899820783052e-05,
#   'r2': 0.9999660379881413,
#   'sensors': ['P520', 'J39', 'P478']},
#  {'node': 'J39',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J40',
#   'linreg': LinearRegression(),
#   'msq': 2.6146126669692283e-05,
#   'r2': 0.9999860345197434,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J41',
#   'linreg': LinearRegression(),
#   'msq': 9.55221435123278e-06,
#   'r2': 0.9999942371935556,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J42',
#   'linreg': LinearRegression(),
#   'msq': 2.676826784766595e-05,
#   'r2': 0.9999901907037224,
#   'sensors': ['J43', 'P174', 'P511']},
#  {'node': 'J43',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J43', 'P511', 'P46']},
#  {'node': 'J44',
#   'linreg': LinearRegression(),
#   'msq': 1.6853223068329703e-05,
#   'r2': 0.9999901005209145,
#   'sensors': ['J43', 'P511', 'P46']},
#  {'node': 'J45',
#   'linreg': LinearRegression(),
#   'msq': 4.127716365942991e-08,
#   'r2': 0.9999999759360989,
#   'sensors': ['P46', 'J62', 'P55']},
#  {'node': 'J46',
#   'linreg': LinearRegression(),
#   'msq': 1.6795619662063338e-05,
#   'r2': 0.9999919970889868,
#   'sensors': ['J43', 'P511', 'P174']},
#  {'node': 'J47',
#   'linreg': LinearRegression(),
#   'msq': 1.5005572492775443e-05,
#   'r2': 0.999990676555814,
#   'sensors': ['J172', 'J43', 'P511']},
#  {'node': 'J48',
#   'linreg': LinearRegression(),
#   'msq': 1.9240967781463365e-05,
#   'r2': 0.9999904230529914,
#   'sensors': ['J172', 'P174', 'J43']},
#  {'node': 'J49',
#   'linreg': LinearRegression(),
#   'msq': 2.5490665243377218e-06,
#   'r2': 0.9999987976390198,
#   'sensors': ['J137', 'P43', 'J33']},
#  {'node': 'J50',
#   'linreg': LinearRegression(),
#   'msq': 0.0002576706142813582,
#   'r2': 0.9999212480592061,
#   'sensors': ['J137', 'P43', 'J33']},
#  {'node': 'J52',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J53',
#   'linreg': LinearRegression(),
#   'msq': 2.368643432749583e-14,
#   'r2': 0.9999999999999907,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J54',
#   'linreg': LinearRegression(),
#   'msq': 2.747092093475523e-29,
#   'r2': 1.0,
#   'sensors': ['J54', 'P46', 'J62']},
#  {'node': 'J56',
#   'linreg': LinearRegression(),
#   'msq': 1.147126725155197e-09,
#   'r2': 0.9999999989616529,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J57',
#   'linreg': LinearRegression(),
#   'msq': 7.239904116391703e-10,
#   'r2': 0.9999999994730977,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J58',
#   'linreg': LinearRegression(),
#   'msq': 1.8425166879257205e-11,
#   'r2': 0.9999999999843229,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J59',
#   'linreg': LinearRegression(),
#   'msq': 2.5581666910374215e-11,
#   'r2': 0.999999999980276,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J60',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J60', 'P52', 'P520']},
#  {'node': 'J61',
#   'linreg': LinearRegression(),
#   'msq': 9.637350581314047e-12,
#   'r2': 0.9999999999926042,
#   'sensors': ['J60', 'P52', 'P520']},
#  {'node': 'J62',
#   'linreg': LinearRegression(),
#   'msq': 2.0194839173657902e-28,
#   'r2': 1.0,
#   'sensors': ['J62', 'P55', 'P204']},
#  {'node': 'J63',
#   'linreg': LinearRegression(),
#   'msq': 9.282963334950215e-09,
#   'r2': 0.9999999940231914,
#   'sensors': ['P56', 'J64', 'J62']},
#  {'node': 'J64',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J64', 'P56', 'J129']},
#  {'node': 'J65',
#   'linreg': LinearRegression(),
#   'msq': 9.331563385327462e-08,
#   'r2': 0.9999999552967718,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J66',
#   'linreg': LinearRegression(),
#   'msq': 5.3663494676928595e-05,
#   'r2': 0.9999737179578018,
#   'sensors': ['J52', 'P45', 'J67']},
#  {'node': 'J67',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J68',
#   'linreg': LinearRegression(),
#   'msq': 1.756446652386658e-08,
#   'r2': 0.9999999910474839,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J69',
#   'linreg': LinearRegression(),
#   'msq': 9.117888442809454e-08,
#   'r2': 0.999999955040127,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J70',
#   'linreg': LinearRegression(),
#   'msq': 1.9909414191723994e-05,
#   'r2': 0.9999927920395765,
#   'sensors': ['J33', 'J151', 'P213']},
#  {'node': 'J71',
#   'linreg': LinearRegression(),
#   'msq': 3.7965900465602405e-05,
#   'r2': 0.9999813238932874,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J72',
#   'linreg': LinearRegression(),
#   'msq': 2.169866337578912e-05,
#   'r2': 0.9999926467573291,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J73',
#   'linreg': LinearRegression(),
#   'msq': 2.4309710174261046e-05,
#   'r2': 0.9999929834069704,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J75',
#   'linreg': LinearRegression(),
#   'msq': 4.328813174718561e-05,
#   'r2': 0.9999793255889682,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J76',
#   'linreg': LinearRegression(),
#   'msq': 2.8915930863485008e-05,
#   'r2': 0.999980264955457,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J77',
#   'linreg': LinearRegression(),
#   'msq': 6.832484142677048e-06,
#   'r2': 0.9999967418004503,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J78',
#   'linreg': LinearRegression(),
#   'msq': 2.9458766251680745e-06,
#   'r2': 0.9999980712084446,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J79',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J80',
#   'linreg': LinearRegression(),
#   'msq': 2.1572965796251537e-07,
#   'r2': 0.999999874429075,
#   'sensors': ['J79', 'P500', 'J67']},
#  {'node': 'J81',
#   'linreg': LinearRegression(),
#   'msq': 2.6071478255953085e-05,
#   'r2': 0.9999874475439298,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J82',
#   'linreg': LinearRegression(),
#   'msq': 4.168444290801601e-05,
#   'r2': 0.9999771277196442,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J83',
#   'linreg': LinearRegression(),
#   'msq': 0.0006242230150012375,
#   'r2': 0.9997145369617603,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J84',
#   'linreg': LinearRegression(),
#   'msq': 7.339323110584557e-05,
#   'r2': 0.9999586902716853,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J85',
#   'linreg': LinearRegression(),
#   'msq': 4.385597584041426e-05,
#   'r2': 0.9999808273504204,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J86',
#   'linreg': LinearRegression(),
#   'msq': 4.244455387727216e-05,
#   'r2': 0.999969281840037,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J87',
#   'linreg': LinearRegression(),
#   'msq': 2.7147155402620064e-06,
#   'r2': 0.9999979483108246,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J88',
#   'linreg': LinearRegression(),
#   'msq': 3.9151727161387016e-06,
#   'r2': 0.9999976923983512,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J89',
#   'linreg': LinearRegression(),
#   'msq': 6.297097492467551e-06,
#   'r2': 0.9999958581459727,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J90',
#   'linreg': LinearRegression(),
#   'msq': 6.2472170884391055e-06,
#   'r2': 0.9999967300510899,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J91',
#   'linreg': LinearRegression(),
#   'msq': 4.7743575856514625e-06,
#   'r2': 0.9999970544503192,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J92',
#   'linreg': LinearRegression(),
#   'msq': 7.710135523897477e-06,
#   'r2': 0.999995925144216,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J93',
#   'linreg': LinearRegression(),
#   'msq': 7.571170625620791e-06,
#   'r2': 0.9999956492327793,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J94',
#   'linreg': LinearRegression(),
#   'msq': 6.663205487888884e-06,
#   'r2': 0.9999955864675711,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J95',
#   'linreg': LinearRegression(),
#   'msq': 7.633152054717291e-08,
#   'r2': 0.9999999467442451,
#   'sensors': ['J12', 'P9', 'P13']},
#  {'node': 'J96',
#   'linreg': LinearRegression(),
#   'msq': 4.444517430952394e-06,
#   'r2': 0.9999979672741446,
#   'sensors': ['P13', 'J17', 'J67']},
#  {'node': 'J97',
#   'linreg': LinearRegression(),
#   'msq': 0.000334805802923146,
#   'r2': 0.9998018236174755,
#   'sensors': ['P13', 'J67', 'P459']},
#  {'node': 'J98',
#   'linreg': LinearRegression(),
#   'msq': 0.00018343644186166828,
#   'r2': 0.9999035359169962,
#   'sensors': ['P13', 'J67', 'P459']},
#  {'node': 'J99',
#   'linreg': LinearRegression(),
#   'msq': 6.417836453270846e-05,
#   'r2': 0.9999505090609567,
#   'sensors': ['J67', 'P459', 'P13']},
#  {'node': 'J100',
#   'linreg': LinearRegression(),
#   'msq': 0.0001263437565226704,
#   'r2': 0.99991094113484,
#   'sensors': ['J67', 'P459', 'P13']},
#  {'node': 'J102',
#   'linreg': LinearRegression(),
#   'msq': 9.428688802546992e-05,
#   'r2': 0.9999390028759167,
#   'sensors': ['J67', 'P459', 'P536']},
#  {'node': 'J103',
#   'linreg': LinearRegression(),
#   'msq': 6.56634053511959e-05,
#   'r2': 0.9999695621552268,
#   'sensors': ['J67', 'P459', 'J163']},
#  {'node': 'J104',
#   'linreg': LinearRegression(),
#   'msq': 2.4252970595189406e-05,
#   'r2': 0.9999857117898211,
#   'sensors': ['J163', 'P536', 'J172']},
#  {'node': 'J105',
#   'linreg': LinearRegression(),
#   'msq': 7.851615310731804e-06,
#   'r2': 0.9999961785203393,
#   'sensors': ['J172', 'J163', 'P174']},
#  {'node': 'J106',
#   'linreg': LinearRegression(),
#   'msq': 6.539685149586359e-06,
#   'r2': 0.9999959477375493,
#   'sensors': ['J172', 'P174', 'J163']},
#  {'node': 'J107',
#   'linreg': LinearRegression(),
#   'msq': 1.7368543473848675e-05,
#   'r2': 0.999990064071559,
#   'sensors': ['J172', 'P174', 'J43']},
#  {'node': 'J108',
#   'linreg': LinearRegression(),
#   'msq': 1.0622454414298464e-05,
#   'r2': 0.9999956267720765,
#   'sensors': ['J67', 'P459', 'J151']},
#  {'node': 'J109',
#   'linreg': LinearRegression(),
#   'msq': 5.865777782852719e-05,
#   'r2': 0.9999717272855556,
#   'sensors': ['J67', 'P459', 'J151']},
#  {'node': 'J110',
#   'linreg': LinearRegression(),
#   'msq': 0.0005207977206532144,
#   'r2': 0.9997228332396221,
#   'sensors': ['J151', 'P213', 'J67']},
#  {'node': 'J111',
#   'linreg': LinearRegression(),
#   'msq': 0.0008303342833750342,
#   'r2': 0.9996911880926843,
#   'sensors': ['J151', 'P213', 'J113']},
#  {'node': 'J112',
#   'linreg': LinearRegression(),
#   'msq': 1.1654657013470273e-05,
#   'r2': 0.9999940612210294,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J113',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J114',
#   'linreg': LinearRegression(),
#   'msq': 1.0506517799690663e-05,
#   'r2': 0.9999942548120938,
#   'sensors': ['J113', 'P110', 'J39']},
#  {'node': 'J115',
#   'linreg': LinearRegression(),
#   'msq': 7.345379910144948e-05,
#   'r2': 0.9999728768640745,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J116',
#   'linreg': LinearRegression(),
#   'msq': 1.424346936492724e-05,
#   'r2': 0.9999939805807673,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J117',
#   'linreg': LinearRegression(),
#   'msq': 1.7775210900154723e-05,
#   'r2': 0.9999900803196577,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J118',
#   'linreg': LinearRegression(),
#   'msq': 0.0001108075222815073,
#   'r2': 0.9999434296937463,
#   'sensors': ['J172', 'P174', 'J43']},
#  {'node': 'J119',
#   'linreg': LinearRegression(),
#   'msq': 5.918879954996834e-06,
#   'r2': 0.9999964392520957,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J120',
#   'linreg': LinearRegression(),
#   'msq': 3.883625432039279e-05,
#   'r2': 0.9999843448537347,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J121',
#   'linreg': LinearRegression(),
#   'msq': 4.016027997878208e-06,
#   'r2': 0.9999972709236769,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J122',
#   'linreg': LinearRegression(),
#   'msq': 2.551493447362202e-06,
#   'r2': 0.9999987846191359,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J123',
#   'linreg': LinearRegression(),
#   'msq': 3.227492906231863e-08,
#   'r2': 0.9999999792135434,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J124',
#   'linreg': LinearRegression(),
#   'msq': 3.89857842157562e-08,
#   'r2': 0.999999967410726,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J125',
#   'linreg': LinearRegression(),
#   'msq': 4.3069313884903344e-08,
#   'r2': 0.9999999762095031,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J126',
#   'linreg': LinearRegression(),
#   'msq': 4.333342033353874e-08,
#   'r2': 0.999999976034761,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J127',
#   'linreg': LinearRegression(),
#   'msq': 3.585534104841282e-10,
#   'r2': 0.9999999997292458,
#   'sensors': ['P244', 'J129', 'J207']},
#  {'node': 'J128',
#   'linreg': LinearRegression(),
#   'msq': 9.737573306676516e-10,
#   'r2': 0.9999999994923355,
#   'sensors': ['P244', 'J129', 'J207']},
#  {'node': 'J129',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J129', 'P244', 'J64']},
#  {'node': 'J130',
#   'linreg': LinearRegression(),
#   'msq': 5.693487936327927e-10,
#   'r2': 0.9999999996974779,
#   'sensors': ['J129', 'P244', 'J64']},
#  {'node': 'J131',
#   'linreg': LinearRegression(),
#   'msq': 2.104192374994266e-13,
#   'r2': 0.9999999999998538,
#   'sensors': ['J60', 'P52', 'P520']},
#  {'node': 'J132',
#   'linreg': LinearRegression(),
#   'msq': 2.435005695426171e-10,
#   'r2': 0.9999999999163565,
#   'sensors': ['J28', 'P22', 'J316']},
#  {'node': 'J133',
#   'linreg': LinearRegression(),
#   'msq': 4.1466083841501144e-05,
#   'r2': 0.999987775426633,
#   'sensors': ['J28', 'P22', 'P27']},
#  {'node': 'J134',
#   'linreg': LinearRegression(),
#   'msq': 0.00018600299853720575,
#   'r2': 0.999935372034113,
#   'sensors': ['J28', 'P27', 'P22']},
#  {'node': 'J135',
#   'linreg': LinearRegression(),
#   'msq': 1.0525856362727358e-06,
#   'r2': 0.9999996230611685,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J136',
#   'linreg': LinearRegression(),
#   'msq': 1.1599199070626696e-06,
#   'r2': 0.9999996234631814,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J137',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J137', 'P43', 'J52']},
#  {'node': 'J138',
#   'linreg': LinearRegression(),
#   'msq': 1.2367274619128194e-06,
#   'r2': 0.9999994393517366,
#   'sensors': ['J33', 'J137', 'P43']},
#  {'node': 'J139',
#   'linreg': LinearRegression(),
#   'msq': 0.0001428660123658616,
#   'r2': 0.9999239084727906,
#   'sensors': ['J33', 'J151', 'P213']},
#  {'node': 'J140',
#   'linreg': LinearRegression(),
#   'msq': 0.0005179997946199445,
#   'r2': 0.9998227197655695,
#   'sensors': ['J33', 'J151', 'P213']},
#  {'node': 'J141',
#   'linreg': LinearRegression(),
#   'msq': 8.781337033014276e-06,
#   'r2': 0.9999964203824367,
#   'sensors': ['J33', 'J146', 'P280']},
#  {'node': 'J142',
#   'linreg': LinearRegression(),
#   'msq': 2.3470392539476724e-06,
#   'r2': 0.9999992130476653,
#   'sensors': ['J316', 'P520', 'J146']},
#  {'node': 'J143',
#   'linreg': LinearRegression(),
#   'msq': 1.2047390668365909e-06,
#   'r2': 0.9999995074481625,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J144',
#   'linreg': LinearRegression(),
#   'msq': 3.6884679840001544e-07,
#   'r2': 0.9999998863716721,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J145',
#   'linreg': LinearRegression(),
#   'msq': 9.456068334672668e-07,
#   'r2': 0.9999995504749624,
#   'sensors': ['J146', 'P280', 'J33']},
#  {'node': 'J146',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J147',
#   'linreg': LinearRegression(),
#   'msq': 4.319288936581239e-08,
#   'r2': 0.9999999839188655,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J148',
#   'linreg': LinearRegression(),
#   'msq': 4.7504551706631394e-05,
#   'r2': 0.9999704834396318,
#   'sensors': ['J67', 'P459', 'J151']},
#  {'node': 'J149',
#   'linreg': LinearRegression(),
#   'msq': 3.579624759981799e-05,
#   'r2': 0.9999813697138038,
#   'sensors': ['J67', 'P459', 'J151']},
#  {'node': 'J150',
#   'linreg': LinearRegression(),
#   'msq': 2.595269049195789e-05,
#   'r2': 0.9999903648072564,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J151',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J153',
#   'linreg': LinearRegression(),
#   'msq': 9.692181888004976e-06,
#   'r2': 0.9999955776565003,
#   'sensors': ['J33', 'J146', 'P280']},
#  {'node': 'J154',
#   'linreg': LinearRegression(),
#   'msq': 8.143617892601751e-07,
#   'r2': 0.9999997358730331,
#   'sensors': ['J146', 'P280', 'J33']},
#  {'node': 'J155',
#   'linreg': LinearRegression(),
#   'msq': 1.2077374609696222e-06,
#   'r2': 0.9999995442296428,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J156',
#   'linreg': LinearRegression(),
#   'msq': 4.930798042738786e-05,
#   'r2': 0.9999823399827139,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J157',
#   'linreg': LinearRegression(),
#   'msq': 6.441872136425002e-05,
#   'r2': 0.9999703610385553,
#   'sensors': ['J146', 'P280', 'J113']},
#  {'node': 'J158',
#   'linreg': LinearRegression(),
#   'msq': 4.299042482997499e-05,
#   'r2': 0.9999782983042004,
#   'sensors': ['J146', 'P280', 'J113']},
#  {'node': 'J159',
#   'linreg': LinearRegression(),
#   'msq': 4.5807669774624824e-05,
#   'r2': 0.9999835830423467,
#   'sensors': ['J146', 'P280', 'J113']},
#  {'node': 'J160',
#   'linreg': LinearRegression(),
#   'msq': 4.83401586202553e-05,
#   'r2': 0.9999684268261815,
#   'sensors': ['J43', 'P174', 'P511']},
#  {'node': 'J161',
#   'linreg': LinearRegression(),
#   'msq': 2.326487070020991e-05,
#   'r2': 0.9999827162189348,
#   'sensors': ['J43', 'P174', 'P511']},
#  {'node': 'J162',
#   'linreg': LinearRegression(),
#   'msq': 4.696713624448683e-06,
#   'r2': 0.9999969536609287,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J163',
#   'linreg': LinearRegression(),
#   'msq': 2.0194839173657902e-28,
#   'r2': 1.0,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J164',
#   'linreg': LinearRegression(),
#   'msq': 1.449439218336643e-05,
#   'r2': 0.9999923560135455,
#   'sensors': ['J163', 'P536', 'J172']},
#  {'node': 'J165',
#   'linreg': LinearRegression(),
#   'msq': 9.763604532308128e-05,
#   'r2': 0.9999462597330065,
#   'sensors': ['J163', 'P536', 'J67']},
#  {'node': 'J166',
#   'linreg': LinearRegression(),
#   'msq': 4.924683925181974e-06,
#   'r2': 0.9999974949940573,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J167',
#   'linreg': LinearRegression(),
#   'msq': 6.486782045710519e-06,
#   'r2': 0.9999968108097332,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J168',
#   'linreg': LinearRegression(),
#   'msq': 1.0794059654799868e-06,
#   'r2': 0.9999994653631391,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J169',
#   'linreg': LinearRegression(),
#   'msq': 0.0001691978366797047,
#   'r2': 0.9999199320930219,
#   'sensors': ['J67', 'P459', 'J172']},
#  {'node': 'J170',
#   'linreg': LinearRegression(),
#   'msq': 0.00030806418439697293,
#   'r2': 0.9998475782911715,
#   'sensors': ['J67', 'P459', 'J172']},
#  {'node': 'J171',
#   'linreg': LinearRegression(),
#   'msq': 4.042277337489197e-05,
#   'r2': 0.9999755275092902,
#   'sensors': ['J172', 'P174', 'J67']},
#  {'node': 'J172',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J172', 'P174', 'J39']},
#  {'node': 'J173',
#   'linreg': LinearRegression(),
#   'msq': 7.970811832797093e-05,
#   'r2': 0.9999568009503369,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J175',
#   'linreg': LinearRegression(),
#   'msq': 3.3866516321832457e-07,
#   'r2': 0.9999998280508966,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J176',
#   'linreg': LinearRegression(),
#   'msq': 1.7379224911139238e-08,
#   'r2': 0.9999999920261659,
#   'sensors': ['J137', 'P43', 'J52']},
#  {'node': 'J177',
#   'linreg': LinearRegression(),
#   'msq': 1.1638640242143354e-09,
#   'r2': 0.9999999994837168,
#   'sensors': ['J137', 'P43', 'J52']},
#  {'node': 'J179',
#   'linreg': LinearRegression(),
#   'msq': 0.060397176842843306,
#   'r2': 0.9796970882541036,
#   'sensors': ['J316', 'P22', 'P520']},
#  {'node': 'J180',
#   'linreg': LinearRegression(),
#   'msq': 0.0007447888324415167,
#   'r2': 0.9996651639142554,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J181',
#   'linreg': LinearRegression(),
#   'msq': 0.001606892446881145,
#   'r2': 0.9994675259070933,
#   'sensors': ['J316', 'J146', 'P280']},
#  {'node': 'J182',
#   'linreg': LinearRegression(),
#   'msq': 0.0015210656722844508,
#   'r2': 0.9992043174281561,
#   'sensors': ['P520', 'J316', 'J146']},
#  {'node': 'J183',
#   'linreg': LinearRegression(),
#   'msq': 1.0351885560998836e-05,
#   'r2': 0.9999960788124538,
#   'sensors': ['P520', 'J316', 'J39']},
#  {'node': 'J184',
#   'linreg': LinearRegression(),
#   'msq': 1.7946146274338657e-05,
#   'r2': 0.9999913116962637,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J185',
#   'linreg': LinearRegression(),
#   'msq': 0.0017697996615549934,
#   'r2': 0.9993303350659031,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J186',
#   'linreg': LinearRegression(),
#   'msq': 0.009998456798495191,
#   'r2': 0.9954224067658205,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J187',
#   'linreg': LinearRegression(),
#   'msq': 0.0006172825117951467,
#   'r2': 0.9997257250849094,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J188',
#   'linreg': LinearRegression(),
#   'msq': 1.3026715642980294e-06,
#   'r2': 0.9999993325502419,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J189',
#   'linreg': LinearRegression(),
#   'msq': 1.0930159591635502,
#   'r2': 0.7282276957424547,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J190',
#   'linreg': LinearRegression(),
#   'msq': 1.0751409887884606,
#   'r2': 0.7215939386501078,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J191',
#   'linreg': LinearRegression(),
#   'msq': 0.0621735553576804,
#   'r2': 0.9524265067776964,
#   'sensors': ['J163', 'P536', 'J67']},
#  {'node': 'J192',
#   'linreg': LinearRegression(),
#   'msq': 0.1517977335849888,
#   'r2': 0.9323769365576134,
#   'sensors': ['J163', 'P536', 'J67']},
#  {'node': 'J193',
#   'linreg': LinearRegression(),
#   'msq': 0.0019014136620060526,
#   'r2': 0.9991123276745932,
#   'sensors': ['J67', 'P459', 'P536']},
#  {'node': 'J194',
#   'linreg': LinearRegression(),
#   'msq': 0.0002420492847083658,
#   'r2': 0.9998364544246268,
#   'sensors': ['J151', 'P213', 'J67']},
#  {'node': 'J195',
#   'linreg': LinearRegression(),
#   'msq': 0.008872406524331945,
#   'r2': 0.9963986455041247,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J196',
#   'linreg': LinearRegression(),
#   'msq': 0.000826507661493427,
#   'r2': 0.9996064686781023,
#   'sensors': ['J151', 'P213', 'J113']},
#  {'node': 'J197',
#   'linreg': LinearRegression(),
#   'msq': 0.00012429206317420734,
#   'r2': 0.9999440216095055,
#   'sensors': ['P520', 'J60', 'J316']},
#  {'node': 'J198',
#   'linreg': LinearRegression(),
#   'msq': 0.0018668081607633748,
#   'r2': 0.9989577847722716,
#   'sensors': ['P520', 'J60', 'J316']},
#  {'node': 'J199',
#   'linreg': LinearRegression(),
#   'msq': 0.00014614305215109348,
#   'r2': 0.9999366303592183,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J200',
#   'linreg': LinearRegression(),
#   'msq': 1.3107414590761265e-05,
#   'r2': 0.9999932895075669,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J202',
#   'linreg': LinearRegression(),
#   'msq': 0.00014610110159245433,
#   'r2': 0.9999460499674631,
#   'sensors': ['P520', 'J316', 'J60']},
#  {'node': 'J203',
#   'linreg': LinearRegression(),
#   'msq': 6.812265691457556e-09,
#   'r2': 0.9999999942829129,
#   'sensors': ['J54', 'P46', 'J62']},
#  {'node': 'J204',
#   'linreg': LinearRegression(),
#   'msq': 2.1272451800308054e-08,
#   'r2': 0.999999986566728,
#   'sensors': ['J54', 'P46', 'J62']},
#  {'node': 'J205',
#   'linreg': LinearRegression(),
#   'msq': 5.125082030702124e-09,
#   'r2': 0.9999999963134386,
#   'sensors': ['P244', 'J129', 'J207']},
#  {'node': 'J206',
#   'linreg': LinearRegression(),
#   'msq': 2.9172377026528853e-08,
#   'r2': 0.9999999761005607,
#   'sensors': ['P244', 'J129', 'J207']},
#  {'node': 'J207',
#   'linreg': LinearRegression(),
#   'msq': 3.044075022499904e-29,
#   'r2': 1.0,
#   'sensors': ['J207', 'J62', 'P55']},
#  {'node': 'J208',
#   'linreg': LinearRegression(),
#   'msq': 5.166777328454746e-07,
#   'r2': 0.9999996915451292,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J209',
#   'linreg': LinearRegression(),
#   'msq': 2.2803352748657597e-05,
#   'r2': 0.9999877086318494,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J210',
#   'linreg': LinearRegression(),
#   'msq': 0.00453942747244147,
#   'r2': 0.9979681041005831,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J211',
#   'linreg': LinearRegression(),
#   'msq': 3.075255504578404e-05,
#   'r2': 0.999986275421186,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J212',
#   'linreg': LinearRegression(),
#   'msq': 0.0005388042195514207,
#   'r2': 0.999797019568969,
#   'sensors': ['J33', 'P27', 'J151']},
#  {'node': 'J213',
#   'linreg': LinearRegression(),
#   'msq': 1.238473073123922e-05,
#   'r2': 0.9999931227320267,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J214',
#   'linreg': LinearRegression(),
#   'msq': 0.01619068529955105,
#   'r2': 0.9919039267191552,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J216',
#   'linreg': LinearRegression(),
#   'msq': 0.0003757304148387861,
#   'r2': 0.9997678092158095,
#   'sensors': ['P536', 'J67', 'P459']},
#  {'node': 'J218',
#   'linreg': LinearRegression(),
#   'msq': 0.0004872444299465948,
#   'r2': 0.9997502395903201,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J219',
#   'linreg': LinearRegression(),
#   'msq': 0.22985920076243524,
#   'r2': 0.9252460143368363,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J220',
#   'linreg': LinearRegression(),
#   'msq': 3.806727429218172e-06,
#   'r2': 0.9999982730047171,
#   'sensors': ['J33', 'J137', 'P43']},
#  {'node': 'J223',
#   'linreg': LinearRegression(),
#   'msq': 0.006393688094775499,
#   'r2': 0.9969157196725676,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J224',
#   'linreg': LinearRegression(),
#   'msq': 0.00044529450352314304,
#   'r2': 0.9997237277912235,
#   'sensors': ['J163', 'P536', 'J172']},
#  {'node': 'J225',
#   'linreg': LinearRegression(),
#   'msq': 1.4350078418674999,
#   'r2': 0.49608325539296305,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J226',
#   'linreg': LinearRegression(),
#   'msq': 0.0015619821203541173,
#   'r2': 0.9991939523377207,
#   'sensors': ['J43', 'P174', 'P511']},
#  {'node': 'J227',
#   'linreg': LinearRegression(),
#   'msq': 0.007472303334570933,
#   'r2': 0.9967356840641551,
#   'sensors': ['J172', 'P174', 'J39']},
#  {'node': 'J228',
#   'linreg': LinearRegression(),
#   'msq': 0.0016474603263763423,
#   'r2': 0.9994541082855017,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J229',
#   'linreg': LinearRegression(),
#   'msq': 0.3134914770799821,
#   'r2': 0.8693512646874011,
#   'sensors': ['J172', 'P174', 'J67']},
#  {'node': 'J230',
#   'linreg': LinearRegression(),
#   'msq': 4.417770094079064e-08,
#   'r2': 0.9999999669414097,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J231',
#   'linreg': LinearRegression(),
#   'msq': 1.614639106613263e-14,
#   'r2': 0.9999999999999888,
#   'sensors': ['J64', 'P56', 'J129']},
#  {'node': 'J232',
#   'linreg': LinearRegression(),
#   'msq': 0.00047056611869230165,
#   'r2': 0.9997214077362422,
#   'sensors': ['P56', 'J64', 'J62']},
#  {'node': 'J233',
#   'linreg': LinearRegression(),
#   'msq': 1.7336751906150717e-08,
#   'r2': 0.9999999939916425,
#   'sensors': ['J137', 'P43', 'J33']},
#  {'node': 'J235',
#   'linreg': LinearRegression(),
#   'msq': 2.635639463500228e-08,
#   'r2': 0.9999999886934704,
#   'sensors': ['J137', 'P43', 'J52']},
#  {'node': 'J236',
#   'linreg': LinearRegression(),
#   'msq': 2.4681764519498525e-08,
#   'r2': 0.9999999887846304,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J239',
#   'linreg': LinearRegression(),
#   'msq': 7.46963115568452e-06,
#   'r2': 0.9999977284334419,
#   'sensors': ['J316', 'J146', 'P280']},
#  {'node': 'J240',
#   'linreg': LinearRegression(),
#   'msq': 0.005107322794806777,
#   'r2': 0.9978576563968573,
#   'sensors': ['P520', 'J316', 'J146']},
#  {'node': 'J241',
#   'linreg': LinearRegression(),
#   'msq': 7.807918199682151e-07,
#   'r2': 0.999999690337757,
#   'sensors': ['J146', 'P280', 'J33']},
#  {'node': 'J242',
#   'linreg': LinearRegression(),
#   'msq': 1.4621123850901055e-06,
#   'r2': 0.9999995041819362,
#   'sensors': ['J146', 'P280', 'J33']},
#  {'node': 'J243',
#   'linreg': LinearRegression(),
#   'msq': 4.10700169448397e-08,
#   'r2': 0.9999999801563404,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J244',
#   'linreg': LinearRegression(),
#   'msq': 4.6403582660059516e-29,
#   'r2': 1.0,
#   'sensors': ['J244', 'P266', 'P22']},
#  {'node': 'J245',
#   'linreg': LinearRegression(),
#   'msq': 0.007199466264145728,
#   'r2': 0.9999921482911264,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J246',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J244', 'P266', 'P22']},
#  {'node': 'J247',
#   'linreg': LinearRegression(),
#   'msq': 0.0007745030086505933,
#   'r2': 0.9996764487414554,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J248',
#   'linreg': LinearRegression(),
#   'msq': 9.111535324645987e-05,
#   'r2': 0.999955602164169,
#   'sensors': ['P520', 'J39', 'P478']},
#  {'node': 'J249',
#   'linreg': LinearRegression(),
#   'msq': 6.1136460589083744e-06,
#   'r2': 0.9999967761882618,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J250',
#   'linreg': LinearRegression(),
#   'msq': 1.3233003423772015e-05,
#   'r2': 0.9999921441954867,
#   'sensors': ['P13', 'J17', 'J67']},
#  {'node': 'J251',
#   'linreg': LinearRegression(),
#   'msq': 8.108523858652472e-06,
#   'r2': 0.9999944238451964,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J252',
#   'linreg': LinearRegression(),
#   'msq': 0.0002652071200065588,
#   'r2': 0.9998021248412357,
#   'sensors': ['J67', 'P459', 'P13']},
#  {'node': 'J253',
#   'linreg': LinearRegression(),
#   'msq': 1.0111905897451514e-05,
#   'r2': 0.9999941812460769,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J254',
#   'linreg': LinearRegression(),
#   'msq': 3.956480583701121e-05,
#   'r2': 0.9999816695696997,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J256',
#   'linreg': LinearRegression(),
#   'msq': 8.978267349742479e-07,
#   'r2': 0.9999996966431067,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J257',
#   'linreg': LinearRegression(),
#   'msq': 5.0947217729543785e-11,
#   'r2': 0.999999999959457,
#   'sensors': ['J54', 'P56', 'P46']},
#  {'node': 'J258',
#   'linreg': LinearRegression(),
#   'msq': 4.330514837688269e-12,
#   'r2': 0.9999999999970585,
#   'sensors': ['J54', 'P46', 'J62']},
#  {'node': 'J259',
#   'linreg': LinearRegression(),
#   'msq': 0.001673233507360944,
#   'r2': 0.9991474969726634,
#   'sensors': ['P539', 'J539', 'P460']},
#  {'node': 'J260',
#   'linreg': LinearRegression(),
#   'msq': 0.0019406167858833424,
#   'r2': 0.9990619336713882,
#   'sensors': ['P539', 'J539', 'J137']},
#  {'node': 'J261',
#   'linreg': LinearRegression(),
#   'msq': 2.0190698336073198e-05,
#   'r2': 0.9999973268017135,
#   'sensors': ['P539', 'J539', 'J137']},
#  {'node': 'J262',
#   'linreg': LinearRegression(),
#   'msq': 0.0015706702336295108,
#   'r2': 0.9993072232905102,
#   'sensors': ['P539', 'J539', 'J137']},
#  {'node': 'J263',
#   'linreg': LinearRegression(),
#   'msq': 0.008621105081792988,
#   'r2': 0.99999124656457,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J264',
#   'linreg': LinearRegression(),
#   'msq': 0.008148744952726234,
#   'r2': 0.9999919581094895,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J265',
#   'linreg': LinearRegression(),
#   'msq': 0.008151813312697417,
#   'r2': 0.9999911078860704,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J267',
#   'linreg': LinearRegression(),
#   'msq': 1.5373877925451216e-05,
#   'r2': 0.9999921303384353,
#   'sensors': ['P460', 'J284', 'P539']},
#  {'node': 'J269',
#   'linreg': LinearRegression(),
#   'msq': 4.014064846235276e-08,
#   'r2': 0.9999999805965116,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J273',
#   'linreg': LinearRegression(),
#   'msq': 2.4639391912812384e-07,
#   'r2': 0.9999998874192348,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J274',
#   'linreg': LinearRegression(),
#   'msq': 0.0001300459494900788,
#   'r2': 0.999951223825892,
#   'sensors': ['P520', 'J316', 'J60']},
#  {'node': 'J275',
#   'linreg': LinearRegression(),
#   'msq': 0.00015546946541783953,
#   'r2': 0.9999453649941853,
#   'sensors': ['P520', 'J316', 'J60']},
#  {'node': 'J276',
#   'linreg': LinearRegression(),
#   'msq': 7.349864264941938e-06,
#   'r2': 0.9999976229081443,
#   'sensors': ['J316', 'J146', 'P280']},
#  {'node': 'J277',
#   'linreg': LinearRegression(),
#   'msq': 1.558962734963384e-05,
#   'r2': 0.9999940441786643,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J278',
#   'linreg': LinearRegression(),
#   'msq': 0.0022485903992944777,
#   'r2': 0.9992528260968238,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J279',
#   'linreg': LinearRegression(),
#   'msq': 3.247724048796557e-10,
#   'r2': 0.9999999997482326,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J280',
#   'linreg': LinearRegression(),
#   'msq': 2.7654865088676965e-06,
#   'r2': 0.999998228500212,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J281',
#   'linreg': LinearRegression(),
#   'msq': 2.102161249437065e-06,
#   'r2': 0.9999985807737531,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J282',
#   'linreg': LinearRegression(),
#   'msq': 5.82660149270119e-05,
#   'r2': 0.999967568754532,
#   'sensors': ['J67', 'P459', 'J52']},
#  {'node': 'J283',
#   'linreg': LinearRegression(),
#   'msq': 4.439227674220656e-05,
#   'r2': 0.9999786074830889,
#   'sensors': ['J67', 'P459', 'J52']},
#  {'node': 'J284',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J284', 'P460', 'P539']},
#  {'node': 'J285',
#   'linreg': LinearRegression(),
#   'msq': 8.860250012786711e-11,
#   'r2': 0.9999999999434163,
#   'sensors': ['J284', 'P460', 'P539']},
#  {'node': 'J286',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J284', 'P460', 'P539']},
#  {'node': 'J287',
#   'linreg': LinearRegression(),
#   'msq': 0.04165140096157339,
#   'r2': 0.9833008086011055,
#   'sensors': ['J316', 'P22', 'P520']},
#  {'node': 'J288',
#   'linreg': LinearRegression(),
#   'msq': 3.840835981286288e-05,
#   'r2': 0.9999897606683014,
#   'sensors': ['J316', 'P22', 'P520']},
#  {'node': 'J289',
#   'linreg': LinearRegression(),
#   'msq': 0.1869502385014228,
#   'r2': 0.9339556387529037,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J290',
#   'linreg': LinearRegression(),
#   'msq': 0.00013864351816794988,
#   'r2': 0.9999264713290068,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J291',
#   'linreg': LinearRegression(),
#   'msq': 0.00013864862662010878,
#   'r2': 0.9999498333822456,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J292',
#   'linreg': LinearRegression(),
#   'msq': 0.0001140397655014795,
#   'r2': 0.9999422094985511,
#   'sensors': ['J172', 'P174', 'J43']},
#  {'node': 'J293',
#   'linreg': LinearRegression(),
#   'msq': 1.1762190744713422e-05,
#   'r2': 0.9999929202828483,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J294',
#   'linreg': LinearRegression(),
#   'msq': 8.213730767906766e-06,
#   'r2': 0.9999953461513711,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J295',
#   'linreg': LinearRegression(),
#   'msq': 1.4984292234086247e-05,
#   'r2': 0.9999929901823332,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J296',
#   'linreg': LinearRegression(),
#   'msq': 5.8404625742353915e-06,
#   'r2': 0.9999970182484834,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J297',
#   'linreg': LinearRegression(),
#   'msq': 4.1195701610561074e-06,
#   'r2': 0.9999981244561912,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J298',
#   'linreg': LinearRegression(),
#   'msq': 1.5147153691460753e-05,
#   'r2': 0.9999952725806696,
#   'sensors': ['P520', 'J316', 'J39']},
#  {'node': 'J299',
#   'linreg': LinearRegression(),
#   'msq': 0.00016804771190038632,
#   'r2': 0.9999346468561858,
#   'sensors': ['P520', 'J39', 'P478']},
#  {'node': 'J300',
#   'linreg': LinearRegression(),
#   'msq': 4.5810952744579916e-05,
#   'r2': 0.9999742842323363,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J301',
#   'linreg': LinearRegression(),
#   'msq': 4.4710811035356574e-05,
#   'r2': 0.9999686996385951,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J302',
#   'linreg': LinearRegression(),
#   'msq': 3.908153325844397e-05,
#   'r2': 0.9999740121282027,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J303',
#   'linreg': LinearRegression(),
#   'msq': 6.906196509597984e-05,
#   'r2': 0.9999642772057652,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J304',
#   'linreg': LinearRegression(),
#   'msq': 0.000907830822058588,
#   'r2': 0.999535895035927,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J305',
#   'linreg': LinearRegression(),
#   'msq': 3.044358256834909e-06,
#   'r2': 0.9999969084955591,
#   'sensors': ['P13', 'J17', 'J12']},
#  {'node': 'J306',
#   'linreg': LinearRegression(),
#   'msq': 8.212811422294417e-07,
#   'r2': 0.9999995769563598,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J307',
#   'linreg': LinearRegression(),
#   'msq': 1.6492621312807803e-07,
#   'r2': 0.9999999003633028,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J308',
#   'linreg': LinearRegression(),
#   'msq': 6.956777026155459e-06,
#   'r2': 0.9999965264818237,
#   'sensors': ['J79', 'P500', 'J67']},
#  {'node': 'J309',
#   'linreg': LinearRegression(),
#   'msq': 8.781535698843723e-08,
#   'r2': 0.9999999574771193,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J310',
#   'linreg': LinearRegression(),
#   'msq': 1.2743900183211862e-06,
#   'r2': 0.9999992357208616,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J311',
#   'linreg': LinearRegression(),
#   'msq': 5.1948617810876634e-05,
#   'r2': 0.9999751072030625,
#   'sensors': ['J172', 'P174', 'J67']},
#  {'node': 'J312',
#   'linreg': LinearRegression(),
#   'msq': 3.0899949347846084e-06,
#   'r2': 0.9999985714191479,
#   'sensors': ['J43', 'P511', 'P46']},
#  {'node': 'J313',
#   'linreg': LinearRegression(),
#   'msq': 5.269045115538428e-06,
#   'r2': 0.9999978821379469,
#   'sensors': ['J43', 'P511', 'J163']},
#  {'node': 'J314',
#   'linreg': LinearRegression(),
#   'msq': 1.7329650212828623e-05,
#   'r2': 0.9999881134898718,
#   'sensors': ['J113', 'P110', 'J39']},
#  {'node': 'J315',
#   'linreg': LinearRegression(),
#   'msq': 3.8157542533099345e-05,
#   'r2': 0.9999739450609263,
#   'sensors': ['J113', 'P110', 'J39']},
#  {'node': 'J316',
#   'linreg': LinearRegression(),
#   'msq': 2.0194839173657902e-28,
#   'r2': 1.0,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J317',
#   'linreg': LinearRegression(),
#   'msq': 5.932338622759407e-06,
#   'r2': 0.9999979199073272,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J318',
#   'linreg': LinearRegression(),
#   'msq': 3.36651015791399e-05,
#   'r2': 0.9999811140431571,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J319',
#   'linreg': LinearRegression(),
#   'msq': 3.3402028700045865e-06,
#   'r2': 0.999998239904321,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J320',
#   'linreg': LinearRegression(),
#   'msq': 2.180155647075498e-07,
#   'r2': 0.999999945922341,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J321',
#   'linreg': LinearRegression(),
#   'msq': 0.13769058817385862,
#   'r2': 0.9940333990393576,
#   'sensors': ['P22', 'J316', 'J28']},
#  {'node': 'J322',
#   'linreg': LinearRegression(),
#   'msq': 1.6178240297128207e-09,
#   'r2': 0.9999999993944506,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J323',
#   'linreg': LinearRegression(),
#   'msq': 8.631884867625945e-05,
#   'r2': 0.999964079232436,
#   'sensors': ['P520', 'J39', 'P478']},
#  {'node': 'J324',
#   'linreg': LinearRegression(),
#   'msq': 5.075345101552645e-05,
#   'r2': 0.9999577570908731,
#   'sensors': ['J67', 'P459', 'J52']},
#  {'node': 'J326',
#   'linreg': LinearRegression(),
#   'msq': 4.96912769919005e-06,
#   'r2': 0.9999972108280781,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J327',
#   'linreg': LinearRegression(),
#   'msq': 1.1442298923546442e-14,
#   'r2': 0.999999999999995,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J539',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J539', 'P539', 'J137']},
#  {'node': 'J544',
#   'linreg': LinearRegression(),
#   'msq': 0.00998374985970252,
#   'r2': 0.9999900617586117,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J546',
#   'linreg': LinearRegression(),
#   'msq': 0.010453328410144578,
#   'r2': 0.9999884296506559,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'T1',
#   'linreg': LinearRegression(),
#   'msq': 0.10297350173375969,
#   'r2': 0.8682289069430114,
#   'sensors': ['P460', 'J284', 'P539']},
#  {'node': 'T2',
#   'linreg': LinearRegression(),
#   'msq': 0.004774553377019648,
#   'r2': 0.9958794212378385,
#   'sensors': ['J54', 'P52', 'P46']}]

# %%
# simulate a leak scenario
sim_LEAK = wntr_WSN.get_sim_results_LEAK(leak_node, leak_area, leak_start, leak_end)

# join pressures and flowrates
sim_LEAK_raw = pd.concat([sim_LEAK.node['pressure'], sim_LEAK.link['flowrate']], axis=1)
predictions = {}

# for each node in graph
G = ng.create_graph()
for node in G.nodes():

    # find linear regression model for this particular node
    for model in linreg_models:
        if model['node'] == node:
            linreg_dict = model

    # choose only the available sensors
    sim_LEAK_scope = sim_LEAK_raw[linreg_dict['sensors']]

    # normalise the input data with respective parameters
    sim_LEAK_scope = (sim_LEAK_scope - normalization_params['mean'].loc[linreg_dict['sensors']]) / normalization_params['std'].loc[linreg_dict['sensors']]

    # predict pressure for each node
    predictions[node] = linreg_dict['linreg'].predict(sim_LEAK_scope)

# "sim_duration*6" because (60 minutes = 10 minutes * 6)
# it's related to simulation step time 
index = [600*i for i in range(0, (sim_duration*6)+1)]

pred_LEAK_results = pd.DataFrame(data=predictions, index=index)
pred_LEAK_results
# Out:
# C:\Users\wij\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\scipy\optimize\minpack.py:829: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Creating a NetworkX graph from .inp file (networkx_graph.py - create_graph())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1701         blocks = _form_blocks(arrays, names, axes)
# -> 1702         mgr = BlockManager(blocks, axes)
#    1703         mgr._consolidate_inplace()
#
# ~\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#
# ~\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     322             if block.shape[1:] != mgr_shape[1:]:
# --> 323                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     324         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (673, 309), indices imply (781, 309)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ad6c6b192f55> in <module>
#      28 index = [600*i for i in range(0, (sim_duration*6)+1)]
#      29
# ---> 30 pred_LEAK_results = pd.DataFrame(data=predictions, index=index)
#      31 pred_LEAK_results
#
# ~\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      93     axes = [columns, index]
#      94
# ---> 95     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      96
#      97
#
# ~\Desktop\Inżynierka\WTNR-pipe-leak-detection-main\virWNTR\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1704         return mgr
#    1705     except ValueError as e:
# -> 1706         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1707
#    1708
#
# ValueError: Shape of passed values is (673, 309), indices imply (781, 309)

# %% [markdown]
# ## Get results of leak scenario

# %%
sim_LEAK_results = pd.concat([sim_LEAK.node['pressure'], sim_LEAK.link['flowrate']], axis=1)
sim_LEAK_results
# Out:
#                 J1         J2         J3         J4         J5         J6  \
# 0        36.011416  30.044852  29.924852  31.958688  32.148688  45.531102
# 3600     36.643471  30.803467  30.683467  32.673468  32.863468  45.903506
# 7200     36.438482  30.598478  30.478478  32.468479  32.658479  45.698517
# 10800    36.233493  30.393490  30.273490  32.263490  32.453490  45.493529
# 14400    36.028505  30.188501  30.068501  32.058502  32.248502  45.288540
# ...            ...        ...        ...        ...        ...        ...
# 2404800  35.267360  29.429958  29.309958  31.299045  31.489045  44.523787
# 2408400  35.057673  29.223796  29.103796  31.091653  31.281653  44.307205
# 2412000  34.753043  28.920796  28.800796  30.788086  30.978086  44.000091
# 2415600  34.448502  28.605903  28.485903  30.476792  30.666792  43.714177
# 2419200  34.592400  28.759888  28.639888  30.627270  30.817270  43.837792
#
#                 J7         J8         J9        J10  ...      P548      P549  \
# 0        31.841401  28.841400  33.861399  43.310270  ...  0.005835 -0.001642
# 3600     32.473456  29.473455  34.493454  43.604068  ...  0.001599 -0.000348
# 7200     32.268468  29.268467  34.288465  43.399079  ...  0.001599 -0.000348
# 10800    32.063479  29.063478  34.083477  43.194090  ...  0.001599 -0.000348
# 14400    31.858490  28.858489  33.878488  42.989102  ...  0.001599 -0.000348
# ...            ...        ...        ...        ...  ...       ...       ...
# 2404800  31.097036  28.097001  33.116992  42.223793  ...  0.002562 -0.000556
# 2408400  30.887490  27.887455  32.907477  42.006064  ...  0.001842 -0.000397
# 2412000  30.582747  27.582680  32.602734  41.698375  ...  0.001672 -0.000357
# 2415600  30.278488  27.278486  32.298485  41.417237  ...  0.002539 -0.000558
# 2419200  30.422386  27.422385  32.442384  41.534449  ... -0.000245  0.000101
#
#              P551      P553     PMP51  PMP63   PMP72     FCV51  FCV63   FCV72
# 0        0.001183 -0.000037  0.020833    0.0  0.0434  0.020833    0.0  0.0434
# 3600     0.000072 -0.000008  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 7200     0.000072 -0.000008  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 10800    0.000072 -0.000008  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 14400    0.000072 -0.000008  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# ...           ...       ...       ...    ...     ...       ...    ...     ...
# 2404800 -0.000079 -0.000022  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 2408400 -0.000146 -0.000022  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 2412000 -0.000163 -0.000022  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 2415600  0.000203 -0.000009  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 2419200 -0.000211 -0.000008  0.000000    0.0  0.0000  0.000000    0.0  0.0000
#
# [673 rows x 679 columns]

# %% [markdown]
# ## Calculate residuum

# %%
residuals = sim_LEAK.node['pressure'] - pred_LEAK_results
residuals
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-34e86df2ff84> in <module>
# ----> 1 residuals = sim_LEAK.node['pressure'] - pred_LEAK_results
#       2 residuals
#
# NameError: name 'pred_LEAK_results' is not defined

# %% [markdown]
# ## Take care of column naming convention

# %%
residuals = residuals.add_suffix('_residuum')

sim_LEAK.node['pressure'] = sim_LEAK.node['pressure'].add_suffix('_pressure')
sim_LEAK.link['flowrate'] = sim_LEAK.link['flowrate'].add_suffix('_flow')
sim_LEAK = pd.concat([sim_LEAK.node['pressure'], sim_LEAK.link['flowrate']], axis=1)

pred_LEAK_results = pred_LEAK_results.add_suffix('_model_output')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-32413a69c989> in <module>
# ----> 1 residuals = residuals.add_suffix('_residuum')
#       2
#       3 sim_LEAK.node['pressure'] = sim_LEAK.node['pressure'].add_suffix('_pressure')
#       4 sim_LEAK.link['flowrate'] = sim_LEAK.link['flowrate'].add_suffix('_flow')
#       5 sim_LEAK = pd.concat([sim_LEAK.node['pressure'], sim_LEAK.link['flowrate']], axis=1)
#
# NameError: name 'residuals' is not defined

# %% [markdown]
# ## Sanity check

# %%
print(f'Number of residuals columns: {len(residuals.columns)}')
print(f'Number of sim_LEAK columns: {len(sim_LEAK.columns)}')
print(f'Number of pred_LEAK_results columns: {len(pred_LEAK_results.columns)}')
print(f'Sum: {len(residuals.columns) + len(sim_LEAK.columns) + len(pred_LEAK_results.columns)}')

# %% [markdown]
# ## Form final dataframe

# %%
output = pd.concat([residuals, sim_LEAK, pred_LEAK_results], axis=1)
output

# %% [markdown]
# ## Export the final dataframe to .xlsx

# %%
if comment:
    output.to_excel(os.path.join(os.getcwd(), f'{method}_n{leak_node}_la{leak_area}_lst{leak_start}_let{leak_end}_{comment}.xlsx'))
else:
    output.to_excel(os.path.join(os.getcwd(), f'{method}_n{leak_node}_la{leak_area}_lst{leak_start}_let{leak_end}.xlsx'))
